# %%
from flask import Flask, render_template, redirect
from flask_pymongo import PyMongo
import urllib.request
import json

# %%
# Create an instance of Flask
app = Flask(__name__)

# Use PyMongo to establish Mongo connection
mongo = PyMongo(app, uri="mongodb://localhost:27017/nypdcrime")

# %%
data = ""
with urllib.request.urlopen("https://data.cityofnewyork.us/resource/uip8-fykc.json") as url:
    data = json.loads(url.read().decode())

# %%
data[0]
# Out:
# {'arrest_key': '206882030',
#  'arrest_date': '2019-12-31T00:00:00.000',
#  'pd_cd': '339',
#  'pd_desc': 'LARCENY,PETIT FROM OPEN AREAS,',
#  'ky_cd': '341.0',
#  'ofns_desc': 'PETIT LARCENY',
#  'law_code': 'PL 1552500',
#  'law_cat_cd': 'M',
#  'arrest_boro': 'M',
#  'arrest_precinct': '24',
#  'jurisdiction_code': '0',
#  'age_group': '45-64',
#  'perp_sex': 'M',
#  'perp_race': 'BLACK',
#  'x_coord_cd': '991075',
#  'y_coord_cd': '227074',
#  'latitude': '40.78994739900003',
#  'longitude': '-73.97535415699997'}

# %%
main_db=mongo.db.nypdcrime

# %%
example_data = data[0]
#for data in data:
 #   example_data.append(data)

# %%
for x in data:
    main_db.insert_one(x)

# %%
# Out:
# [{'arrest_key': '206882030',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '339',
#   'pd_desc': 'LARCENY,PETIT FROM OPEN AREAS,',
#   'ky_cd': '341.0',
#   'ofns_desc': 'PETIT LARCENY',
#   'law_code': 'PL 1552500',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'M',
#   'arrest_precinct': '24',
#   'jurisdiction_code': '0',
#   'age_group': '45-64',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '991075',
#   'y_coord_cd': '227074',
#   'latitude': '40.78994739900003',
#   'longitude': '-73.97535415699997',
#   '_id': ObjectId('5e69839830510e762f61ae4a')},
#  {'arrest_key': '206882732',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '922',
#   'pd_desc': 'TRAFFIC,UNCLASSIFIED MISDEMEAN',
#   'ky_cd': '348.0',
#   'ofns_desc': 'VEHICLE AND TRAFFIC LAWS',
#   'law_code': 'VTL0511001',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'B',
#   'arrest_precinct': '52',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'WHITE HISPANIC',
#   'x_coord_cd': '1010546',
#   'y_coord_cd': '253615',
#   'latitude': '40.86275836700002',
#   'longitude': '-73.90493406199994'},
#  {'arrest_key': '206881424',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '905',
#   'pd_desc': 'INTOXICATED DRIVING,ALCOHOL',
#   'ky_cd': '347.0',
#   'ofns_desc': 'INTOXICATED & IMPAIRED DRIVING',
#   'law_code': 'VTL11920U3',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'Q',
#   'arrest_precinct': '112',
#   'jurisdiction_code': '0',
#   'age_group': '45-64',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1025401',
#   'y_coord_cd': '202586',
#   'latitude': '40.722640996000045',
#   'longitude': '-73.85154182199994'},
#  {'arrest_key': '206886643',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '397',
#   'pd_desc': 'ROBBERY,OPEN AREA UNCLASSIFIED',
#   'ky_cd': '105.0',
#   'ofns_desc': 'ROBBERY',
#   'law_code': 'PL 1600500',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'M',
#   'arrest_precinct': '5',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK HISPANIC',
#   'x_coord_cd': '984984',
#   'y_coord_cd': '200116',
#   'latitude': '40.71595711700007',
#   'longitude': '-73.997353676'},
#  {'arrest_key': '206882633',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '510',
#   'pd_desc': 'CONTROLLED SUBSTANCE, INTENT T',
#   'ky_cd': '117.0',
#   'ofns_desc': 'DANGEROUS DRUGS',
#   'law_code': 'PL 2200601',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'B',
#   'arrest_precinct': '44',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'WHITE HISPANIC',
#   'x_coord_cd': '1004749',
#   'y_coord_cd': '240880',
#   'latitude': '40.827819901000055',
#   'longitude': '-73.92593075599996'},
#  {'arrest_key': '206890202',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '339',
#   'pd_desc': 'LARCENY,PETIT FROM OPEN AREAS,',
#   'ky_cd': '341.0',
#   'ofns_desc': 'PETIT LARCENY',
#   'law_code': 'PL 1552500',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'M',
#   'arrest_precinct': '1',
#   'jurisdiction_code': '0',
#   'age_group': '18-24',
#   'perp_sex': 'F',
#   'perp_race': 'ASIAN / PACIFIC ISLANDER',
#   'x_coord_cd': '984722',
#   'y_coord_cd': '202914',
#   'latitude': '40.723636973000055',
#   'longitude': '-73.99829859799998'},
#  {'arrest_key': '206884735',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '105',
#   'pd_desc': 'STRANGULATION 1ST',
#   'ky_cd': '106.0',
#   'ofns_desc': 'FELONY ASSAULT',
#   'law_code': 'PL 1211200',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'B',
#   'arrest_precinct': '43',
#   'jurisdiction_code': '0',
#   'age_group': '18-24',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK HISPANIC',
#   'x_coord_cd': '1018791',
#   'y_coord_cd': '240921',
#   'latitude': '40.82788868500006',
#   'longitude': '-73.87519150199995'},
#  {'arrest_key': '206888492',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '113',
#   'pd_desc': 'MENACING,UNCLASSIFIED',
#   'ky_cd': '344.0',
#   'ofns_desc': 'ASSAULT 3 & RELATED OFFENSES',
#   'law_code': 'PL 1201401',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'K',
#   'arrest_precinct': '81',
#   'jurisdiction_code': '0',
#   'age_group': '45-64',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1005312',
#   'y_coord_cd': '190540',
#   'latitude': '40.68964821100008',
#   'longitude': '-73.92405412199997'},
#  {'arrest_key': '206886051',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '139',
#   'pd_desc': 'MURDER,UNCLASSIFIED',
#   'ky_cd': '101.0',
#   'ofns_desc': 'MURDER & NON-NEGL. MANSLAUGHTE',
#   'law_code': 'PL 1252501',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'K',
#   'arrest_precinct': '81',
#   'jurisdiction_code': '0',
#   'age_group': '18-24',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1005312',
#   'y_coord_cd': '190540',
#   'latitude': '40.68964821100008',
#   'longitude': '-73.92405412199997'},
#  {'arrest_key': '206883995',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '718',
#   'pd_desc': 'FRAUD,UNCLASSIFIED-MISDEMEANOR',
#   'ky_cd': '340.0',
#   'ofns_desc': 'FRAUDS',
#   'law_code': 'PL 1906001',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'M',
#   'arrest_precinct': '5',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'ASIAN / PACIFIC ISLANDER',
#   'x_coord_cd': '983907',
#   'y_coord_cd': '199959',
#   'latitude': '40.71552621300003',
#   'longitude': '-74.00123874799993'},
#  {'arrest_key': '206883652',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '639',
#   'pd_desc': 'AGGRAVATED HARASSMENT 2',
#   'ky_cd': '361.0',
#   'ofns_desc': 'OFF. AGNST PUB ORD SENSBLTY &',
#   'law_code': 'PL 2403002',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'B',
#   'arrest_precinct': '40',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'WHITE HISPANIC',
#   'x_coord_cd': '1005041',
#   'y_coord_cd': '234533',
#   'latitude': '40.810398494000026',
#   'longitude': '-73.92489531099994'},
#  {'arrest_key': '206887260',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '764',
#   'pd_desc': 'BAIL JUMPING 1 & 2',
#   'ky_cd': '126.0',
#   'ofns_desc': 'MISCELLANEOUS PENAL LAW',
#   'law_code': 'PL 2155700',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'M',
#   'arrest_precinct': '5',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'F',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '983907',
#   'y_coord_cd': '199959',
#   'latitude': '40.71552621300003',
#   'longitude': '-74.00123874799993'},
#  {'arrest_key': '206887259',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '397',
#   'pd_desc': 'ROBBERY,OPEN AREA UNCLASSIFIED',
#   'ky_cd': '105.0',
#   'ofns_desc': 'ROBBERY',
#   'law_code': 'PL 1600500',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'M',
#   'arrest_precinct': '32',
#   'jurisdiction_code': '0',
#   'age_group': '<18',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1000844',
#   'y_coord_cd': '235760',
#   'latitude': '40.81377514600007',
#   'longitude': '-73.94005366399993'},
#  {'arrest_key': '206889595',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '339',
#   'pd_desc': 'LARCENY,PETIT FROM OPEN AREAS,',
#   'ky_cd': '341.0',
#   'ofns_desc': 'PETIT LARCENY',
#   'law_code': 'PL 1552500',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'S',
#   'arrest_precinct': '121',
#   'jurisdiction_code': '0',
#   'age_group': '18-24',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '938676',
#   'y_coord_cd': '153149',
#   'latitude': '40.58692579000007',
#   'longitude': '-74.16408371599994'},
#  {'arrest_key': '206885153',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '748',
#   'pd_desc': 'CONTEMPT,CRIMINAL',
#   'ky_cd': '359.0',
#   'ofns_desc': 'OFFENSES AGAINST PUBLIC ADMINI',
#   'law_code': 'PL 2155003',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'M',
#   'arrest_precinct': '10',
#   'jurisdiction_code': '2',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '982992',
#   'y_coord_cd': '210566',
#   'latitude': '40.74463975500004',
#   'longitude': '-74.00454140599999'},
#  {'arrest_key': '206885155',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '101',
#   'pd_desc': 'ASSAULT 3',
#   'ky_cd': '344.0',
#   'ofns_desc': 'ASSAULT 3 & RELATED OFFENSES',
#   'law_code': 'PL 1200001',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'Q',
#   'arrest_precinct': '105',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'WHITE HISPANIC',
#   'x_coord_cd': '1057174',
#   'y_coord_cd': '199402',
#   'latitude': '40.71369686100008',
#   'longitude': '-73.73695004899997'},
#  {'arrest_key': '206891083',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '101',
#   'pd_desc': 'ASSAULT 3',
#   'ky_cd': '344.0',
#   'ofns_desc': 'ASSAULT 3 & RELATED OFFENSES',
#   'law_code': 'PL 1200001',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'M',
#   'arrest_precinct': '14',
#   'jurisdiction_code': '0',
#   'age_group': '18-24',
#   'perp_sex': 'M',
#   'perp_race': 'WHITE',
#   'x_coord_cd': '987215',
#   'y_coord_cd': '215403',
#   'latitude': '40.75791569300002',
#   'longitude': '-73.98929901999998'},
#  {'arrest_key': '206888899',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '339',
#   'pd_desc': 'LARCENY,PETIT FROM OPEN AREAS,',
#   'ky_cd': '341.0',
#   'ofns_desc': 'PETIT LARCENY',
#   'law_code': 'PL 1552500',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'K',
#   'arrest_precinct': '94',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'F',
#   'perp_race': 'WHITE HISPANIC',
#   'x_coord_cd': '997053',
#   'y_coord_cd': '204934',
#   'latitude': '40.729172131000034',
#   'longitude': '-73.95380781799997'},
#  {'arrest_key': '206889272',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '339',
#   'pd_desc': 'LARCENY,PETIT FROM OPEN AREAS,',
#   'ky_cd': '341.0',
#   'ofns_desc': 'PETIT LARCENY',
#   'law_code': 'PL 1552500',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'K',
#   'arrest_precinct': '70',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '999240',
#   'y_coord_cd': '169262',
#   'latitude': '40.631257160000075',
#   'longitude': '-73.94599639799998'},
#  {'arrest_key': '206888903',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '339',
#   'pd_desc': 'LARCENY,PETIT FROM OPEN AREAS,',
#   'ky_cd': '341.0',
#   'ofns_desc': 'PETIT LARCENY',
#   'law_code': 'PL 1552500',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'M',
#   'arrest_precinct': '14',
#   'jurisdiction_code': '6',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '986781',
#   'y_coord_cd': '212761',
#   'latitude': '40.750664208000046',
#   'longitude': '-73.99086657499998'},
#  {'arrest_key': '206882028',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '922',
#   'pd_desc': 'TRAFFIC,UNCLASSIFIED MISDEMEAN',
#   'ky_cd': '348.0',
#   'ofns_desc': 'VEHICLE AND TRAFFIC LAWS',
#   'law_code': 'VTL05110MU',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'M',
#   'arrest_precinct': '10',
#   'jurisdiction_code': '0',
#   'age_group': '45-64',
#   'perp_sex': 'M',
#   'perp_race': 'ASIAN / PACIFIC ISLANDER',
#   'x_coord_cd': '984456',
#   'y_coord_cd': '215989',
#   'latitude': '40.75952460900004',
#   'longitude': '-73.99925785699998'},
#  {'arrest_key': '206882025',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '792',
#   'pd_desc': 'WEAPONS POSSESSION 1 & 2',
#   'ky_cd': '118.0',
#   'ofns_desc': 'DANGEROUS WEAPONS',
#   'law_code': 'PL 265031B',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'K',
#   'arrest_precinct': '77',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1001639',
#   'y_coord_cd': '185922',
#   'latitude': '40.676980833000066',
#   'longitude': '-73.93731047899996'},
#  {'arrest_key': '206884278',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '339',
#   'pd_desc': 'LARCENY,PETIT FROM OPEN AREAS,',
#   'ky_cd': '341.0',
#   'ofns_desc': 'PETIT LARCENY',
#   'law_code': 'PL 1552500',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'Q',
#   'arrest_precinct': '103',
#   'jurisdiction_code': '0',
#   'age_group': '65+',
#   'perp_sex': 'M',
#   'perp_race': 'WHITE HISPANIC',
#   'x_coord_cd': '1041894',
#   'y_coord_cd': '196417',
#   'latitude': '40.705616513000045',
#   'longitude': '-73.79209337499998'},
#  {'arrest_key': '206883654',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '905',
#   'pd_desc': 'INTOXICATED DRIVING,ALCOHOL',
#   'ky_cd': '347.0',
#   'ofns_desc': 'INTOXICATED & IMPAIRED DRIVING',
#   'law_code': 'VTL11920U3',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'Q',
#   'arrest_precinct': '104',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'WHITE HISPANIC',
#   'x_coord_cd': '1019624',
#   'y_coord_cd': '200827',
#   'latitude': '40.71783795600004',
#   'longitude': '-73.87239259899997'},
#  {'arrest_key': '206889269',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '503',
#   'pd_desc': 'CONTROLLED SUBSTANCE,INTENT TO',
#   'ky_cd': '117.0',
#   'ofns_desc': 'DANGEROUS DRUGS',
#   'law_code': 'PL 2201601',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'B',
#   'arrest_precinct': '52',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK HISPANIC',
#   'x_coord_cd': '1013734',
#   'y_coord_cd': '254081',
#   'latitude': '40.86402732400006',
#   'longitude': '-73.89340651099997'},
#  {'arrest_key': '206888897',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '339',
#   'pd_desc': 'LARCENY,PETIT FROM OPEN AREAS,',
#   'ky_cd': '341.0',
#   'ofns_desc': 'PETIT LARCENY',
#   'law_code': 'PL 1552500',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'B',
#   'arrest_precinct': '40',
#   'jurisdiction_code': '0',
#   'age_group': '45-64',
#   'perp_sex': 'M',
#   'perp_race': 'WHITE HISPANIC',
#   'x_coord_cd': '1009673',
#   'y_coord_cd': '235504',
#   'latitude': '40.81305150300005',
#   'longitude': '-73.90815884499993'},
#  {'arrest_key': '206889580',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '729',
#   'pd_desc': 'FORGERY,ETC.,UNCLASSIFIED-FELO',
#   'ky_cd': '113.0',
#   'ofns_desc': 'FORGERY',
#   'law_code': 'PL 1701003',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'B',
#   'arrest_precinct': '43',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'WHITE HISPANIC',
#   'x_coord_cd': '1023479',
#   'y_coord_cd': '238790',
#   'latitude': '40.822020125000044',
#   'longitude': '-73.85826443799994'},
#  {'arrest_key': '206882207',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '105',
#   'pd_desc': 'STRANGULATION 1ST',
#   'ky_cd': '106.0',
#   'ofns_desc': 'FELONY ASSAULT',
#   'law_code': 'PL 1211200',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'Q',
#   'arrest_precinct': '106',
#   'jurisdiction_code': '0',
#   'age_group': '45-64',
#   'perp_sex': 'M',
#   'perp_race': 'UNKNOWN',
#   'x_coord_cd': '1028843',
#   'y_coord_cd': '188006',
#   'latitude': '40.682605696000046',
#   'longitude': '-73.83922075699996'},
#  {'arrest_key': '206889582',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '779',
#   'pd_desc': 'PUBLIC ADMINISTRATION,UNCLASSI',
#   'ky_cd': '126.0',
#   'ofns_desc': 'MISCELLANEOUS PENAL LAW',
#   'law_code': 'PL 215510D',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'K',
#   'arrest_precinct': '61',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'F',
#   'perp_race': 'WHITE',
#   'x_coord_cd': '1002930',
#   'y_coord_cd': '153521',
#   'latitude': '40.58804433800003',
#   'longitude': '-73.93274583799997'},
#  {'arrest_key': '206893597',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '109',
#   'pd_desc': 'ASSAULT 2,1,UNCLASSIFIED',
#   'ky_cd': '106.0',
#   'ofns_desc': 'FELONY ASSAULT',
#   'law_code': 'PL 1200501',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'M',
#   'arrest_precinct': '9',
#   'jurisdiction_code': '2',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '990896',
#   'y_coord_cd': '201774',
#   'latitude': '40.72050546500003',
#   'longitude': '-73.976025587'},
#  {'arrest_key': '206882733',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '847',
#   'pd_desc': 'NY STATE LAWS,UNCLASSIFIED FEL',
#   'ky_cd': '125.0',
#   'ofns_desc': 'NYS LAWS-UNCLASSIFIED FELONY',
#   'law_code': 'VTL05110FE',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'B',
#   'arrest_precinct': '47',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1025261',
#   'y_coord_cd': '257260',
#   'latitude': '40.872706675000074',
#   'longitude': '-73.85171299799998'},
#  {'arrest_key': '206884273',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '109',
#   'pd_desc': 'ASSAULT 2,1,UNCLASSIFIED',
#   'ky_cd': '106.0',
#   'ofns_desc': 'FELONY ASSAULT',
#   'law_code': 'PL 1200501',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'K',
#   'arrest_precinct': '63',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'F',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1001308',
#   'y_coord_cd': '168329',
#   'latitude': '40.62869253100007',
#   'longitude': '-73.93854829599996'},
#  {'arrest_key': '206886636',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '397',
#   'pd_desc': 'ROBBERY,OPEN AREA UNCLASSIFIED',
#   'ky_cd': '105.0',
#   'ofns_desc': 'ROBBERY',
#   'law_code': 'PL 1601503',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'K',
#   'arrest_precinct': '60',
#   'jurisdiction_code': '0',
#   'age_group': '<18',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '989547',
#   'y_coord_cd': '148969',
#   'latitude': '40.57556809600004',
#   'longitude': '-73.98093364699997'},
#  {'arrest_key': '206890431',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '139',
#   'pd_desc': 'MURDER,UNCLASSIFIED',
#   'ky_cd': '101.0',
#   'ofns_desc': 'MURDER & NON-NEGL. MANSLAUGHTE',
#   'law_code': 'PL 1252501',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'M',
#   'arrest_precinct': '34',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1002162',
#   'y_coord_cd': '249364',
#   'latitude': '40.851111636000034',
#   'longitude': '-73.93525591199995'},
#  {'arrest_key': '206885159',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '244',
#   'pd_desc': 'BURGLARY,UNCLASSIFIED,UNKNOWN',
#   'ky_cd': '107.0',
#   'ofns_desc': 'BURGLARY',
#   'law_code': 'PL 1402000',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'Q',
#   'arrest_precinct': '109',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1032084',
#   'y_coord_cd': '216954',
#   'latitude': '40.762043893000055',
#   'longitude': '-73.82732958099997'},
#  {'arrest_key': '206890918',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '799',
#   'pd_desc': 'PUBLIC SAFETY,UNCLASSIFIED MIS',
#   'ky_cd': '363.0',
#   'ofns_desc': 'OFFENSES AGAINST PUBLIC SAFETY',
#   'law_code': 'PL 2700502',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'K',
#   'arrest_precinct': '79',
#   'jurisdiction_code': '2',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'WHITE HISPANIC',
#   'x_coord_cd': '997621',
#   'y_coord_cd': '194157',
#   'latitude': '40.699590998000076',
#   'longitude': '-73.95177985899994'},
#  {'arrest_key': '206882024',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '101',
#   'pd_desc': 'ASSAULT 3',
#   'ky_cd': '344.0',
#   'ofns_desc': 'ASSAULT 3 & RELATED OFFENSES',
#   'law_code': 'PL 1200001',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'K',
#   'arrest_precinct': '71',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'F',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1001010',
#   'y_coord_cd': '179064',
#   'latitude': '40.65815836400003',
#   'longitude': '-73.93959520299995'},
#  {'arrest_key': '206885161',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '922',
#   'pd_desc': 'TRAFFIC,UNCLASSIFIED MISDEMEAN',
#   'ky_cd': '348.0',
#   'ofns_desc': 'VEHICLE AND TRAFFIC LAWS',
#   'law_code': 'VTL0511001',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'Q',
#   'arrest_precinct': '113',
#   'jurisdiction_code': '97',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK HISPANIC',
#   'x_coord_cd': '1046315',
#   'y_coord_cd': '187088',
#   'latitude': '40.67998073800004',
#   'longitude': '-73.77623390699993'},
#  {'arrest_key': '206882205',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '905',
#   'pd_desc': 'INTOXICATED DRIVING,ALCOHOL',
#   'ky_cd': '347.0',
#   'ofns_desc': 'INTOXICATED & IMPAIRED DRIVING',
#   'law_code': 'VTL11920U3',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'K',
#   'arrest_precinct': '72',
#   'jurisdiction_code': '0',
#   'age_group': '45-64',
#   'perp_sex': 'M',
#   'perp_race': 'WHITE',
#   'x_coord_cd': '985224',
#   'y_coord_cd': '182902',
#   'latitude': '40.668708633000044',
#   'longitude': '-73.99649040699995'},
#  {'arrest_key': '206891601',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '259',
#   'pd_desc': 'CRIMINAL MISCHIEF,UNCLASSIFIED 4',
#   'ky_cd': '351.0',
#   'ofns_desc': 'CRIMINAL MISCHIEF & RELATED OF',
#   'law_code': 'PL 1450001',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'K',
#   'arrest_precinct': '72',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '983024',
#   'y_coord_cd': '177659',
#   'latitude': '40.654317721000034',
#   'longitude': '-74.00441992599998'},
#  {'arrest_key': '206887599',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '339',
#   'pd_desc': 'LARCENY,PETIT FROM OPEN AREAS,',
#   'ky_cd': '341.0',
#   'ofns_desc': 'PETIT LARCENY',
#   'law_code': 'PL 1552500',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'K',
#   'arrest_precinct': '60',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'WHITE',
#   'x_coord_cd': '994447',
#   'y_coord_cd': '151043',
#   'latitude': '40.58125653700006',
#   'longitude': '-73.96329182299998'},
#  {'arrest_key': '206885152',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '106',
#   'pd_desc': 'ASSAULT POLICE/PEACE OFFICER',
#   'ky_cd': '106.0',
#   'ofns_desc': 'FELONY ASSAULT',
#   'law_code': 'PL 1200800',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'M',
#   'arrest_precinct': '5',
#   'jurisdiction_code': '72',
#   'age_group': '18-24',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '984146',
#   'y_coord_cd': '200403',
#   'latitude': '40.71674489400005',
#   'longitude': '-74.00037661299997'},
#  {'arrest_key': '206886057',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '339',
#   'pd_desc': 'LARCENY,PETIT FROM OPEN AREAS,',
#   'ky_cd': '341.0',
#   'ofns_desc': 'PETIT LARCENY',
#   'law_code': 'PL 1552500',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'M',
#   'arrest_precinct': '13',
#   'jurisdiction_code': '0',
#   'age_group': '45-64',
#   'perp_sex': 'M',
#   'perp_race': 'WHITE HISPANIC',
#   'x_coord_cd': '990238',
#   'y_coord_cd': '209365',
#   'latitude': '40.74134137300007',
#   'longitude': '-73.97839260899997'},
#  {'arrest_key': '206889588',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '439',
#   'pd_desc': 'LARCENY,GRAND FROM OPEN AREAS, UNATTENDED',
#   'ky_cd': '109.0',
#   'ofns_desc': 'GRAND LARCENY',
#   'law_code': 'PL 1553001',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'M',
#   'arrest_precinct': '14',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'ASIAN / PACIFIC ISLANDER',
#   'x_coord_cd': '987220',
#   'y_coord_cd': '212676',
#   'latitude': '40.75043076800005',
#   'longitude': '-73.98928217599996'},
#  {'arrest_key': '206892341',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '397',
#   'pd_desc': 'ROBBERY,OPEN AREA UNCLASSIFIED',
#   'ky_cd': '105.0',
#   'ofns_desc': 'ROBBERY',
#   'law_code': 'PL 1600500',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'K',
#   'arrest_precinct': '67',
#   'jurisdiction_code': '0',
#   'age_group': '18-24',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK HISPANIC',
#   'x_coord_cd': '1004940',
#   'y_coord_cd': '180941',
#   'latitude': '40.66330200400005',
#   'longitude': '-73.92542497899994'},
#  {'arrest_key': '206890961',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '511',
#   'pd_desc': 'CONTROLLED SUBSTANCE, POSSESSI',
#   'ky_cd': '235.0',
#   'ofns_desc': 'DANGEROUS DRUGS',
#   'law_code': 'PL 2200300',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'B',
#   'arrest_precinct': '50',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1009226',
#   'y_coord_cd': '257932',
#   'latitude': '40.87461104400006',
#   'longitude': '-73.90969013799997'},
#  {'arrest_key': '206892350',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '105',
#   'pd_desc': 'STRANGULATION 1ST',
#   'ky_cd': '106.0',
#   'ofns_desc': 'FELONY ASSAULT',
#   'law_code': 'PL 1211300',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'K',
#   'arrest_precinct': '84',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '988897',
#   'y_coord_cd': '192615',
#   'latitude': '40.69536744700008',
#   'longitude': '-73.98324342499996'},
#  {'arrest_key': '206882033',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '922',
#   'pd_desc': 'TRAFFIC,UNCLASSIFIED MISDEMEAN',
#   'ky_cd': '348.0',
#   'ofns_desc': 'VEHICLE AND TRAFFIC LAWS',
#   'law_code': 'VTL1220B01',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'Q',
#   'arrest_precinct': '115',
#   'jurisdiction_code': '97',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'ASIAN / PACIFIC ISLANDER',
#   'x_coord_cd': '1018714',
#   'y_coord_cd': '214946',
#   'latitude': '40.756594678000056',
#   'longitude': '-73.87560301799994'},
#  {'arrest_key': '206887261',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '339',
#   'pd_desc': 'LARCENY,PETIT FROM OPEN AREAS,',
#   'ky_cd': '341.0',
#   'ofns_desc': 'PETIT LARCENY',
#   'law_code': 'PL 1552500',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'M',
#   'arrest_precinct': '25',
#   'jurisdiction_code': '0',
#   'age_group': '45-64',
#   'perp_sex': 'M',
#   'perp_race': 'WHITE HISPANIC',
#   'x_coord_cd': '1002996',
#   'y_coord_cd': '229133',
#   'latitude': '40.795581553000034',
#   'longitude': '-73.93229781499997'},
#  {'arrest_key': '206891074',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '113',
#   'pd_desc': 'MENACING,UNCLASSIFIED',
#   'ky_cd': '344.0',
#   'ofns_desc': 'ASSAULT 3 & RELATED OFFENSES',
#   'law_code': 'PL 1201401',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'K',
#   'arrest_precinct': '70',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '994453',
#   'y_coord_cd': '176817',
#   'latitude': '40.65200082200005',
#   'longitude': '-73.96323127899994'},
#  {'arrest_key': '206887263',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '114',
#   'pd_desc': 'OBSTR BREATH/CIRCUL',
#   'ky_cd': '344.0',
#   'ofns_desc': 'ASSAULT 3 & RELATED OFFENSES',
#   'law_code': 'PL 1211100',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'S',
#   'arrest_precinct': '120',
#   'jurisdiction_code': '0',
#   'age_group': '18-24',
#   'perp_sex': 'F',
#   'perp_race': 'WHITE HISPANIC',
#   'x_coord_cd': '960040',
#   'y_coord_cd': '174186',
#   'latitude': '40.64475207900006',
#   'longitude': '-74.08724138199995'},
#  {'arrest_key': '206891084',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '441',
#   'pd_desc': 'LARCENY,GRAND OF AUTO',
#   'ky_cd': '110.0',
#   'ofns_desc': 'GRAND LARCENY OF MOTOR VEHICLE',
#   'law_code': 'PL 1553008',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'M',
#   'arrest_precinct': '14',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'WHITE',
#   'x_coord_cd': '985994',
#   'y_coord_cd': '213198',
#   'latitude': '40.75186385300003',
#   'longitude': '-73.99370689799997'},
#  {'arrest_key': '206886046',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '922',
#   'pd_desc': 'TRAFFIC,UNCLASSIFIED MISDEMEAN',
#   'ky_cd': '348.0',
#   'ofns_desc': 'VEHICLE AND TRAFFIC LAWS',
#   'law_code': 'VTL05110MU',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'B',
#   'arrest_precinct': '50',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1009323',
#   'y_coord_cd': '260387',
#   'latitude': '40.88134898200008',
#   'longitude': '-73.90933020499993'},
#  {'arrest_key': '206891079',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '503',
#   'pd_desc': 'CONTROLLED SUBSTANCE,INTENT TO',
#   'ky_cd': '117.0',
#   'ofns_desc': 'DANGEROUS DRUGS',
#   'law_code': 'PL 2201601',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'M',
#   'arrest_precinct': '28',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '997020',
#   'y_coord_cd': '230319',
#   'latitude': '40.79884745600003',
#   'longitude': '-73.95387866199997'},
#  {'arrest_key': '206890204',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '905',
#   'pd_desc': 'INTOXICATED DRIVING,ALCOHOL',
#   'ky_cd': '347.0',
#   'ofns_desc': 'INTOXICATED & IMPAIRED DRIVING',
#   'law_code': 'VTL11920U3',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'S',
#   'arrest_precinct': '121',
#   'jurisdiction_code': '0',
#   'age_group': '45-64',
#   'perp_sex': 'M',
#   'perp_race': 'WHITE HISPANIC',
#   'x_coord_cd': '930664',
#   'y_coord_cd': '154427',
#   'latitude': '40.59038882200008',
#   'longitude': '-74.19293975599999'},
#  {'arrest_key': '206891615',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '750',
#   'pd_desc': 'RESISTING ARREST',
#   'ky_cd': '359.0',
#   'ofns_desc': 'OFFENSES AGAINST PUBLIC ADMINI',
#   'law_code': 'PL 2053000',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'Q',
#   'arrest_precinct': '103',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1037513',
#   'y_coord_cd': '194902',
#   'latitude': '40.70148565900007',
#   'longitude': '-73.80790651999997'},
#  {'arrest_key': '206887603',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '339',
#   'pd_desc': 'LARCENY,PETIT FROM OPEN AREAS,',
#   'ky_cd': '341.0',
#   'ofns_desc': 'PETIT LARCENY',
#   'law_code': 'PL 1552500',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'K',
#   'arrest_precinct': '75',
#   'jurisdiction_code': '0',
#   'age_group': '45-64',
#   'perp_sex': 'F',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1020754',
#   'y_coord_cd': '176733',
#   'latitude': '40.65170090400005',
#   'longitude': '-73.86844675099996'},
#  {'arrest_key': '206890440',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '268',
#   'pd_desc': 'CRIMINAL MIS 2 & 3',
#   'ky_cd': '121.0',
#   'ofns_desc': 'CRIMINAL MISCHIEF & RELATED OF',
#   'law_code': 'PL 1450502',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'Q',
#   'arrest_precinct': '114',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1001955',
#   'y_coord_cd': '216397',
#   'latitude': '40.760626741000074',
#   'longitude': '-73.93609107899994'},
#  {'arrest_key': '206889577',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '510',
#   'pd_desc': 'CONTROLLED SUBSTANCE, INTENT T',
#   'ky_cd': '117.0',
#   'ofns_desc': 'DANGEROUS DRUGS',
#   'law_code': 'PL 2200601',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'B',
#   'arrest_precinct': '47',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1021895',
#   'y_coord_cd': '259481',
#   'latitude': '40.87881762600006',
#   'longitude': '-73.86387135299998'},
#  {'arrest_key': '206888079',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '259',
#   'pd_desc': 'CRIMINAL MISCHIEF,UNCLASSIFIED 4',
#   'ky_cd': '351.0',
#   'ofns_desc': 'CRIMINAL MISCHIEF & RELATED OF',
#   'law_code': 'PL 1450001',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'B',
#   'arrest_precinct': '43',
#   'jurisdiction_code': '97',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1022831',
#   'y_coord_cd': '244452',
#   'latitude': '40.83756353000007',
#   'longitude': '-73.86057314099996'},
#  {'arrest_key': '206888902',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '922',
#   'pd_desc': 'TRAFFIC,UNCLASSIFIED MISDEMEAN',
#   'ky_cd': '348.0',
#   'ofns_desc': 'VEHICLE AND TRAFFIC LAWS',
#   'law_code': 'VTL0511001',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'M',
#   'arrest_precinct': '34',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1007190',
#   'y_coord_cd': '253954',
#   'latitude': '40.86369817700007',
#   'longitude': '-73.91706577199994'},
#  {'arrest_key': '206886642',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '397',
#   'pd_desc': 'ROBBERY,OPEN AREA UNCLASSIFIED',
#   'ky_cd': '105.0',
#   'ofns_desc': 'ROBBERY',
#   'law_code': 'PL 1600500',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'M',
#   'arrest_precinct': '5',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK HISPANIC',
#   'x_coord_cd': '984984',
#   'y_coord_cd': '200116',
#   'latitude': '40.71595711700007',
#   'longitude': '-73.997353676'},
#  {'arrest_key': '206890920',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '507',
#   'pd_desc': 'CONTROLLED SUBSTANCE, POSSESSI',
#   'ky_cd': '117.0',
#   'ofns_desc': 'DANGEROUS DRUGS',
#   'law_code': 'PL 2200602',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'K',
#   'arrest_precinct': '79',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1001139',
#   'y_coord_cd': '192775',
#   'latitude': '40.69579171600003',
#   'longitude': '-73.939095905'},
#  {'arrest_key': '206886644',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '397',
#   'pd_desc': 'ROBBERY,OPEN AREA UNCLASSIFIED',
#   'ky_cd': '105.0',
#   'ofns_desc': 'ROBBERY',
#   'law_code': 'PL 1600500',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'M',
#   'arrest_precinct': '5',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK HISPANIC',
#   'x_coord_cd': '984984',
#   'y_coord_cd': '200116',
#   'latitude': '40.71595711700007',
#   'longitude': '-73.997353676'},
#  {'arrest_key': '206890969',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '681',
#   'pd_desc': 'CHILD, ENDANGERING WELFARE',
#   'ky_cd': '233.0',
#   'ofns_desc': 'SEX CRIMES',
#   'law_code': 'PL 2601002',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'M',
#   'arrest_precinct': '26',
#   'jurisdiction_code': '2',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '996241',
#   'y_coord_cd': '236149',
#   'latitude': '40.81485028900005',
#   'longitude': '-73.95668184799997'},
#  {'arrest_key': '206892353',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '109',
#   'pd_desc': 'ASSAULT 2,1,UNCLASSIFIED',
#   'ky_cd': '106.0',
#   'ofns_desc': 'FELONY ASSAULT',
#   'law_code': 'PL 1200501',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'M',
#   'arrest_precinct': '9',
#   'jurisdiction_code': '2',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '990896',
#   'y_coord_cd': '201774',
#   'latitude': '40.72050546500003',
#   'longitude': '-73.976025587'},
#  {'arrest_key': '206883651',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '109',
#   'pd_desc': 'ASSAULT 2,1,UNCLASSIFIED',
#   'ky_cd': '106.0',
#   'ofns_desc': 'FELONY ASSAULT',
#   'law_code': 'PL 1200501',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'B',
#   'arrest_precinct': '44',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'F',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1008941',
#   'y_coord_cd': '243348',
#   'latitude': '40.83458312700003',
#   'longitude': '-73.91077438799994'},
#  {'arrest_key': '206888084',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '739',
#   'pd_desc': 'FRAUD,UNCLASSIFIED-FELONY',
#   'ky_cd': '112.0',
#   'ofns_desc': 'THEFT-FRAUD',
#   'law_code': 'PL 1908301',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'Q',
#   'arrest_precinct': '101',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK HISPANIC',
#   'x_coord_cd': '1055868',
#   'y_coord_cd': '156522',
#   'latitude': '40.596011813000075',
#   'longitude': '-73.74211638099996'},
#  {'arrest_key': '206890965',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '750',
#   'pd_desc': 'RESISTING ARREST',
#   'ky_cd': '359.0',
#   'ofns_desc': 'OFFENSES AGAINST PUBLIC ADMINI',
#   'law_code': 'PL 2053000',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'B',
#   'arrest_precinct': '52',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK HISPANIC',
#   'x_coord_cd': '1017852',
#   'y_coord_cd': '260301',
#   'latitude': '40.88108458800008',
#   'longitude': '-73.87848732899994'},
#  {'arrest_key': '206891075',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '494',
#   'pd_desc': 'STOLEN PROPERTY 2,1,POSSESSION',
#   'ky_cd': '111.0',
#   'ofns_desc': 'POSSESSION OF STOLEN PROPERTY',
#   'law_code': 'PL 1655000',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'K',
#   'arrest_precinct': '61',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'WHITE',
#   'x_coord_cd': '996737',
#   'y_coord_cd': '153014',
#   'latitude': '40.58666361100006',
#   'longitude': '-73.95504408999993'},
#  {'arrest_key': '206882737',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '112',
#   'pd_desc': 'MENACING 1ST DEGREE (VICT NOT',
#   'ky_cd': '126.0',
#   'ofns_desc': 'MISCELLANEOUS PENAL LAW',
#   'law_code': 'PL 1201300',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'M',
#   'arrest_precinct': '25',
#   'jurisdiction_code': '2',
#   'age_group': '45-64',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1001322',
#   'y_coord_cd': '235045',
#   'latitude': '40.81181176000007',
#   'longitude': '-73.93832865099995'},
#  {'arrest_key': '206886048',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '139',
#   'pd_desc': 'MURDER,UNCLASSIFIED',
#   'ky_cd': '101.0',
#   'ofns_desc': 'MURDER & NON-NEGL. MANSLAUGHTE',
#   'law_code': 'PL 1252501',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'B',
#   'arrest_precinct': '46',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK HISPANIC',
#   'x_coord_cd': '1011751',
#   'y_coord_cd': '250275',
#   'latitude': '40.85358740100002',
#   'longitude': '-73.90059135599995'},
#  {'arrest_key': '206889864',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '101',
#   'pd_desc': 'ASSAULT 3',
#   'ky_cd': '344.0',
#   'ofns_desc': 'ASSAULT 3 & RELATED OFFENSES',
#   'law_code': 'PL 1200001',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'B',
#   'arrest_precinct': '47',
#   'jurisdiction_code': '0',
#   'age_group': '45-64',
#   'perp_sex': 'F',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1022822',
#   'y_coord_cd': '263521',
#   'latitude': '40.88990214800003',
#   'longitude': '-73.86049591899997'},
#  {'arrest_key': '206891605',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '259',
#   'pd_desc': 'CRIMINAL MISCHIEF,UNCLASSIFIED 4',
#   'ky_cd': '351.0',
#   'ofns_desc': 'CRIMINAL MISCHIEF & RELATED OF',
#   'law_code': 'PL 1450001',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'K',
#   'arrest_precinct': '72',
#   'jurisdiction_code': '0',
#   'age_group': '18-24',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '983024',
#   'y_coord_cd': '177659',
#   'latitude': '40.654317721000034',
#   'longitude': '-74.00441992599998'},
#  {'arrest_key': '206882634',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '792',
#   'pd_desc': 'WEAPONS POSSESSION 1 & 2',
#   'ky_cd': '118.0',
#   'ofns_desc': 'DANGEROUS WEAPONS',
#   'law_code': 'PL 265031B',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'K',
#   'arrest_precinct': '75',
#   'jurisdiction_code': '2',
#   'age_group': '45-64',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1017183',
#   'y_coord_cd': '185588',
#   'latitude': '40.67601990000002',
#   'longitude': '-73.88127280599997'},
#  {'arrest_key': '206891815',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '792',
#   'pd_desc': 'WEAPONS POSSESSION 1 & 2',
#   'ky_cd': '118.0',
#   'ofns_desc': 'DANGEROUS WEAPONS',
#   'law_code': 'PL 265031B',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'K',
#   'arrest_precinct': '79',
#   'jurisdiction_code': '0',
#   'age_group': '45-64',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '997446',
#   'y_coord_cd': '188937',
#   'latitude': '40.68526356700004',
#   'longitude': '-73.95242120999995'},
#  {'arrest_key': '206890975',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '339',
#   'pd_desc': 'LARCENY,PETIT FROM OPEN AREAS,',
#   'ky_cd': '341.0',
#   'ofns_desc': 'PETIT LARCENY',
#   'law_code': 'PL 1552500',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'M',
#   'arrest_precinct': '23',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'WHITE HISPANIC',
#   'x_coord_cd': '999353',
#   'y_coord_cd': '225822',
#   'latitude': '40.786500725000046',
#   'longitude': '-73.94546242799998'},
#  {'arrest_key': '206887602',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '639',
#   'pd_desc': 'AGGRAVATED HARASSMENT 2',
#   'ky_cd': '361.0',
#   'ofns_desc': 'OFF. AGNST PUB ORD SENSBLTY &',
#   'law_code': 'PL 2403002',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'K',
#   'arrest_precinct': '60',
#   'jurisdiction_code': '0',
#   'age_group': '45-64',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '990824',
#   'y_coord_cd': '149705',
#   'latitude': '40.57758741600002',
#   'longitude': '-73.97633607099993'},
#  {'arrest_key': '206885162',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '101',
#   'pd_desc': 'ASSAULT 3',
#   'ky_cd': '344.0',
#   'ofns_desc': 'ASSAULT 3 & RELATED OFFENSES',
#   'law_code': 'PL 1200001',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'Q',
#   'arrest_precinct': '114',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'WHITE HISPANIC',
#   'x_coord_cd': '1001857',
#   'y_coord_cd': '212462',
#   'latitude': '40.74982636300007',
#   'longitude': '-73.93645513699995'},
#  {'arrest_key': '206882204',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '511',
#   'pd_desc': 'CONTROLLED SUBSTANCE, POSSESSI',
#   'ky_cd': '235.0',
#   'ofns_desc': 'DANGEROUS DRUGS',
#   'law_code': 'PL 2200300',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'B',
#   'arrest_precinct': '46',
#   'jurisdiction_code': '0',
#   'age_group': '45-64',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1012009',
#   'y_coord_cd': '253420',
#   'latitude': '40.86221867200004',
#   'longitude': '-73.89964571999997'},
#  {'arrest_key': '206884276',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '109',
#   'pd_desc': 'ASSAULT 2,1,UNCLASSIFIED',
#   'ky_cd': '106.0',
#   'ofns_desc': 'FELONY ASSAULT',
#   'law_code': 'PL 1200501',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'M',
#   'arrest_precinct': '23',
#   'jurisdiction_code': '0',
#   'age_group': '45-64',
#   'perp_sex': 'F',
#   'perp_race': 'WHITE',
#   'x_coord_cd': '998829',
#   'y_coord_cd': '226859',
#   'latitude': '40.78934789300007',
#   'longitude': '-73.94735241299998'},
#  {'arrest_key': '206883991',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '139',
#   'pd_desc': 'MURDER,UNCLASSIFIED',
#   'ky_cd': '101.0',
#   'ofns_desc': 'MURDER & NON-NEGL. MANSLAUGHTE',
#   'law_code': 'PL 1252501',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'B',
#   'arrest_precinct': '44',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1006537',
#   'y_coord_cd': '244511',
#   'latitude': '40.83778161800007',
#   'longitude': '-73.91945797099999'},
#  {'arrest_key': '206885151',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '339',
#   'pd_desc': 'LARCENY,PETIT FROM OPEN AREAS,',
#   'ky_cd': '341.0',
#   'ofns_desc': 'PETIT LARCENY',
#   'law_code': 'PL 1552500',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'M',
#   'arrest_precinct': '14',
#   'jurisdiction_code': '0',
#   'age_group': '45-64',
#   'perp_sex': 'M',
#   'perp_race': 'WHITE',
#   'x_coord_cd': '986455',
#   'y_coord_cd': '213102',
#   'latitude': '40.75160025400004',
#   'longitude': '-73.99204306099993'},
#  {'arrest_key': '206885160',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '244',
#   'pd_desc': 'BURGLARY,UNCLASSIFIED,UNKNOWN',
#   'ky_cd': '107.0',
#   'ofns_desc': 'BURGLARY',
#   'law_code': 'PL 1402000',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'Q',
#   'arrest_precinct': '109',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1032084',
#   'y_coord_cd': '216954',
#   'latitude': '40.762043893000055',
#   'longitude': '-73.82732958099997'},
#  {'arrest_key': '206884272',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '478',
#   'pd_desc': 'THEFT OF SERVICES, UNCLASSIFIE',
#   'ky_cd': '343.0',
#   'ofns_desc': 'OTHER OFFENSES RELATED TO THEF',
#   'law_code': 'PL 1651503',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'K',
#   'arrest_precinct': '73',
#   'jurisdiction_code': '1',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1005571',
#   'y_coord_cd': '181640',
#   'latitude': '40.66521910700004',
#   'longitude': '-73.92314834999998'},
#  {'arrest_key': '206890436',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '101',
#   'pd_desc': 'ASSAULT 3',
#   'ky_cd': '344.0',
#   'ofns_desc': 'ASSAULT 3 & RELATED OFFENSES',
#   'law_code': 'PL 1200001',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'M',
#   'arrest_precinct': '9',
#   'jurisdiction_code': '2',
#   'age_group': '25-44',
#   'perp_sex': 'F',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '990954',
#   'y_coord_cd': '203046',
#   'latitude': '40.72399675400004',
#   'longitude': '-73.97581508199994'},
#  {'arrest_key': '206886052',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '779',
#   'pd_desc': 'PUBLIC ADMINISTRATION,UNCLASSI',
#   'ky_cd': '126.0',
#   'ofns_desc': 'MISCELLANEOUS PENAL LAW',
#   'law_code': 'PL 215510B',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'K',
#   'arrest_precinct': '83',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1006422',
#   'y_coord_cd': '192976',
#   'latitude': '40.69633175600006',
#   'longitude': '-73.92004356399997'},
#  {'arrest_key': '206891607',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '511',
#   'pd_desc': 'CONTROLLED SUBSTANCE, POSSESSI',
#   'ky_cd': '235.0',
#   'ofns_desc': 'DANGEROUS DRUGS',
#   'law_code': 'PL 2200300',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'K',
#   'arrest_precinct': '76',
#   'jurisdiction_code': '0',
#   'age_group': '18-24',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '982885',
#   'y_coord_cd': '185703',
#   'latitude': '40.67639669900007',
#   'longitude': '-74.00492250999997'},
#  {'arrest_key': '206882629',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '397',
#   'pd_desc': 'ROBBERY,OPEN AREA UNCLASSIFIED',
#   'ky_cd': '105.0',
#   'ofns_desc': 'ROBBERY',
#   'law_code': 'PL 1600500',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'B',
#   'arrest_precinct': '40',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK HISPANIC',
#   'x_coord_cd': '1004950',
#   'y_coord_cd': '232897',
#   'latitude': '40.80590834100008',
#   'longitude': '-73.92522908799998'},
#  {'arrest_key': '206890201',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '748',
#   'pd_desc': 'CONTEMPT,CRIMINAL',
#   'ky_cd': '359.0',
#   'ofns_desc': 'OFFENSES AGAINST PUBLIC ADMINI',
#   'law_code': 'PL 2155006',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'K',
#   'arrest_precinct': '63',
#   'jurisdiction_code': '0',
#   'age_group': '45-64',
#   'perp_sex': 'F',
#   'perp_race': 'WHITE',
#   'x_coord_cd': '1009348',
#   'y_coord_cd': '167036',
#   'latitude': '40.625124389000064',
#   'longitude': '-73.90958821899994'},
#  {'arrest_key': '206888900',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '339',
#   'pd_desc': 'LARCENY,PETIT FROM OPEN AREAS,',
#   'ky_cd': '341.0',
#   'ofns_desc': 'PETIT LARCENY',
#   'law_code': 'PL 1552500',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'K',
#   'arrest_precinct': '84',
#   'jurisdiction_code': '0',
#   'age_group': '18-24',
#   'perp_sex': 'F',
#   'perp_race': 'ASIAN / PACIFIC ISLANDER',
#   'x_coord_cd': '987004',
#   'y_coord_cd': '191535',
#   'latitude': '40.69240388700007',
#   'longitude': '-73.99007040599997'},
#  {'arrest_key': '206890427',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '109',
#   'pd_desc': 'ASSAULT 2,1,UNCLASSIFIED',
#   'ky_cd': '106.0',
#   'ofns_desc': 'FELONY ASSAULT',
#   'law_code': 'PL 1200501',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'K',
#   'arrest_precinct': '83',
#   'jurisdiction_code': '0',
#   'age_group': '18-24',
#   'perp_sex': 'M',
#   'perp_race': 'WHITE HISPANIC',
#   'x_coord_cd': '1007128',
#   'y_coord_cd': '193705',
#   'latitude': '40.69833089400004',
#   'longitude': '-73.91749507299994'},
#  {'arrest_key': '206888490',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '101',
#   'pd_desc': 'ASSAULT 3',
#   'ky_cd': '344.0',
#   'ofns_desc': 'ASSAULT 3 & RELATED OFFENSES',
#   'law_code': 'PL 1200001',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'B',
#   'arrest_precinct': '42',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'F',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1011125',
#   'y_coord_cd': '241994',
#   'latitude': '40.83086041200004',
#   'longitude': '-73.90288739199997'},
#  {'arrest_key': '206891810',
#   'arrest_date': '2019-12-31T00:00:00.000',
#   'pd_cd': '862',
# ...
#  {'arrest_key': '206865327',
#   'arrest_date': '2019-12-28T00:00:00.000',
#   'pd_cd': '511',
#   'pd_desc': 'CONTROLLED SUBSTANCE, POSSESSI',
#   'ky_cd': '235.0',
#   'ofns_desc': 'DANGEROUS DRUGS',
#   'law_code': 'PL 2200300',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'K',
#   'arrest_precinct': '83',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'WHITE HISPANIC',
#   'x_coord_cd': '1002104',
#   'y_coord_cd': '193290',
#   'latitude': '40.697203377000044',
#   'longitude': '-73.93561453399997'},
#  {'arrest_key': '206865565',
#   'arrest_date': '2019-12-28T00:00:00.000',
#   'pd_cd': '792',
#   'pd_desc': 'WEAPONS POSSESSION 1 & 2',
#   'ky_cd': '118.0',
#   'ofns_desc': 'DANGEROUS WEAPONS',
#   'law_code': 'PL 2650801',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'B',
#   'arrest_precinct': '43',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1020183',
#   'y_coord_cd': '239283',
#   'latitude': '40.82338729100008',
#   'longitude': '-73.87017045'},
#  {'arrest_key': '206865832',
#   'arrest_date': '2019-12-28T00:00:00.000',
#   'pd_cd': '113',
#   'pd_desc': 'MENACING,UNCLASSIFIED',
#   'ky_cd': '344.0',
#   'ofns_desc': 'ASSAULT 3 & RELATED OFFENSES',
#   'law_code': 'PL 1201401',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'K',
#   'arrest_precinct': '72',
#   'jurisdiction_code': '0',
#   'age_group': '18-24',
#   'perp_sex': 'M',
#   'perp_race': 'WHITE HISPANIC',
#   'x_coord_cd': '978719',
#   'y_coord_cd': '174095',
#   'latitude': '40.64453366900005',
#   'longitude': '-74.01993215099996'},
#  {'arrest_key': '206865840',
#   'arrest_date': '2019-12-28T00:00:00.000',
#   'pd_cd': '511',
#   'pd_desc': 'CONTROLLED SUBSTANCE, POSSESSI',
#   'ky_cd': '235.0',
#   'ofns_desc': 'DANGEROUS DRUGS',
#   'law_code': 'PL 2200300',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'K',
#   'arrest_precinct': '79',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '998208',
#   'y_coord_cd': '186492',
#   'latitude': '40.67855142900004',
#   'longitude': '-73.94967876499999'},
#  {'arrest_key': '206864431',
#   'arrest_date': '2019-12-28T00:00:00.000',
#   'pd_cd': '511',
#   'pd_desc': 'CONTROLLED SUBSTANCE, POSSESSI',
#   'ky_cd': '235.0',
#   'ofns_desc': 'DANGEROUS DRUGS',
#   'law_code': 'PL 2200300',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'B',
#   'arrest_precinct': '40',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1006520',
#   'y_coord_cd': '236780',
#   'latitude': '40.81656227600007',
#   'longitude': '-73.91954506799993'},
#  {'arrest_key': '206861075',
#   'arrest_date': '2019-12-28T00:00:00.000',
#   'pd_cd': '905',
#   'pd_desc': 'INTOXICATED DRIVING,ALCOHOL',
#   'ky_cd': '347.0',
#   'ofns_desc': 'INTOXICATED & IMPAIRED DRIVING',
#   'law_code': 'VTL11920U2',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'M',
#   'arrest_precinct': '17',
#   'jurisdiction_code': '0',
#   'age_group': '45-64',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '993097',
#   'y_coord_cd': '214529',
#   'latitude': '40.75551285800003',
#   'longitude': '-73.96806857099993'},
#  {'arrest_key': '206861067',
#   'arrest_date': '2019-12-28T00:00:00.000',
#   'pd_cd': '759',
#   'pd_desc': 'PUBLIC ADMINISTATION,UNCLASS M',
#   'ky_cd': '359.0',
#   'ofns_desc': 'OFFENSES AGAINST PUBLIC ADMINI',
#   'law_code': 'PL 1950002',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'B',
#   'arrest_precinct': '44',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1005981',
#   'y_coord_cd': '245427',
#   'latitude': '40.84029715700007',
#   'longitude': '-73.921464342'},
#  {'arrest_key': '206866035',
#   'arrest_date': '2019-12-28T00:00:00.000',
#   'pd_cd': '109',
#   'pd_desc': 'ASSAULT 2,1,UNCLASSIFIED',
#   'ky_cd': '106.0',
#   'ofns_desc': 'FELONY ASSAULT',
#   'law_code': 'PL 1200501',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'B',
#   'arrest_precinct': '46',
#   'jurisdiction_code': '0',
#   'age_group': '<18',
#   'perp_sex': 'F',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1012314',
#   'y_coord_cd': '252560',
#   'latitude': '40.859857267000045',
#   'longitude': '-73.89854667099996'},
#  {'arrest_key': '206860973',
#   'arrest_date': '2019-12-28T00:00:00.000',
#   'pd_cd': '792',
#   'pd_desc': 'WEAPONS POSSESSION 1 & 2',
#   'ky_cd': '118.0',
#   'ofns_desc': 'DANGEROUS WEAPONS',
#   'law_code': 'PL 265031B',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'B',
#   'arrest_precinct': '46',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'WHITE HISPANIC',
#   'x_coord_cd': '1010496',
#   'y_coord_cd': '249163',
#   'latitude': '40.85053911200004',
#   'longitude': '-73.90513225699993'},
#  {'arrest_key': '206860596',
#   'arrest_date': '2019-12-28T00:00:00.000',
#   'pd_cd': '922',
#   'pd_desc': 'TRAFFIC,UNCLASSIFIED MISDEMEAN',
#   'ky_cd': '348.0',
#   'ofns_desc': 'VEHICLE AND TRAFFIC LAWS',
#   'law_code': 'VTL05110MU',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'Q',
#   'arrest_precinct': '111',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'WHITE HISPANIC',
#   'x_coord_cd': '1051537',
#   'y_coord_cd': '217093',
#   'latitude': '40.76229876300005',
#   'longitude': '-73.75710677699995'},
#  {'arrest_key': '206860592',
#   'arrest_date': '2019-12-28T00:00:00.000',
#   'pd_cd': '904',
#   'pd_desc': 'INTOXICATED DRIVING,ALCOHOL',
#   'ky_cd': '119.0',
#   'ofns_desc': 'INTOXICATED/IMPAIRED DRIVING',
#   'law_code': 'VTL11920E2',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'M',
#   'arrest_precinct': '24',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '993369',
#   'y_coord_cd': '229307',
#   'latitude': '40.79607431300008',
#   'longitude': '-73.96706674599994'},
#  {'arrest_key': '206866322',
#   'arrest_date': '2019-12-28T00:00:00.000',
#   'pd_cd': '339',
#   'pd_desc': 'LARCENY,PETIT FROM OPEN AREAS,',
#   'ky_cd': '341.0',
#   'ofns_desc': 'PETIT LARCENY',
#   'law_code': 'PL 1552500',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'M',
#   'arrest_precinct': '24',
#   'jurisdiction_code': '0',
#   'age_group': '18-24',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '993893',
#   'y_coord_cd': '227458',
#   'latitude': '40.79099875000002',
#   'longitude': '-73.965176892'},
#  {'arrest_key': '206863151',
#   'arrest_date': '2019-12-28T00:00:00.000',
#   'pd_cd': '198',
#   'pd_desc': 'CRIMINAL CONTEMPT 1',
#   'ky_cd': '126.0',
#   'ofns_desc': 'MISCELLANEOUS PENAL LAW',
#   'law_code': 'PL 21551B3',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'K',
#   'arrest_precinct': '61',
#   'jurisdiction_code': '0',
#   'age_group': '18-24',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '991001',
#   'y_coord_cd': '154995',
#   'latitude': '40.59210728500005',
#   'longitude': '-73.97569361599994'},
#  {'arrest_key': '206866476',
#   'arrest_date': '2019-12-28T00:00:00.000',
#   'pd_cd': '113',
#   'pd_desc': 'MENACING,UNCLASSIFIED',
#   'ky_cd': '344.0',
#   'ofns_desc': 'ASSAULT 3 & RELATED OFFENSES',
#   'law_code': 'PL 1201401',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'Q',
#   'arrest_precinct': '107',
#   'jurisdiction_code': '0',
#   'age_group': '<18',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1041576',
#   'y_coord_cd': '198968',
#   'latitude': '40.71262045200007',
#   'longitude': '-73.79321860199997'},
#  {'arrest_key': '206866477',
#   'arrest_date': '2019-12-28T00:00:00.000',
#   'pd_cd': '139',
#   'pd_desc': 'MURDER,UNCLASSIFIED',
#   'ky_cd': '101.0',
#   'ofns_desc': 'MURDER & NON-NEGL. MANSLAUGHTE',
#   'law_code': 'PL 1252501',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'S',
#   'arrest_precinct': '121',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '942825',
#   'y_coord_cd': '166367',
#   'latitude': '40.623226819000074',
#   'longitude': '-74.14922697299994'},
#  {'arrest_key': '206860861',
#   'arrest_date': '2019-12-28T00:00:00.000',
#   'pd_cd': '339',
#   'pd_desc': 'LARCENY,PETIT FROM OPEN AREAS,',
#   'ky_cd': '341.0',
#   'ofns_desc': 'PETIT LARCENY',
#   'law_code': 'PL 1552500',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'M',
#   'arrest_precinct': '24',
#   'jurisdiction_code': '0',
#   'age_group': '45-64',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '991075',
#   'y_coord_cd': '227074',
#   'latitude': '40.78994739900003',
#   'longitude': '-73.97535415699997'},
#  {'arrest_key': '206864443',
#   'arrest_date': '2019-12-28T00:00:00.000',
#   'pd_cd': '748',
#   'pd_desc': 'CONTEMPT,CRIMINAL',
#   'ky_cd': '359.0',
#   'ofns_desc': 'OFFENSES AGAINST PUBLIC ADMINI',
#   'law_code': 'PL 2155003',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'S',
#   'arrest_precinct': '123',
#   'jurisdiction_code': '0',
#   'age_group': '65+',
#   'perp_sex': 'M',
#   'perp_race': 'WHITE',
#   'x_coord_cd': '914928',
#   'y_coord_cd': '125757',
#   'latitude': '40.51158633800003',
#   'longitude': '-74.24930372699998'},
#  {'arrest_key': '206864708',
#   'arrest_date': '2019-12-28T00:00:00.000',
#   'pd_cd': '339',
#   'pd_desc': 'LARCENY,PETIT FROM OPEN AREAS,',
#   'ky_cd': '341.0',
#   'ofns_desc': 'PETIT LARCENY',
#   'law_code': 'PL 1552500',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'K',
#   'arrest_precinct': '70',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '999240',
#   'y_coord_cd': '169262',
#   'latitude': '40.631257160000075',
#   'longitude': '-73.94599639799998'},
#  {'arrest_key': '206863976',
#   'arrest_date': '2019-12-28T00:00:00.000',
#   'pd_cd': '101',
#   'pd_desc': 'ASSAULT 3',
#   'ky_cd': '344.0',
#   'ofns_desc': 'ASSAULT 3 & RELATED OFFENSES',
#   'law_code': 'PL 1200001',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'M',
#   'arrest_precinct': '24',
#   'jurisdiction_code': '0',
#   'age_group': '45-64',
#   'perp_sex': 'M',
#   'perp_race': 'WHITE',
#   'x_coord_cd': '993043',
#   'y_coord_cd': '227779',
#   'latitude': '40.79188069500003',
#   'longitude': '-73.96824614599996'},
#  {'arrest_key': '206863973',
#   'arrest_date': '2019-12-28T00:00:00.000',
#   'pd_cd': '969',
#   'pd_desc': 'TRAFFIC,UNCLASSIFIED INFRACTIO',
#   'ky_cd': '881.0',
#   'ofns_desc': 'OTHER TRAFFIC INFRACTION',
#   'law_code': 'VTL051101A',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'K',
#   'arrest_precinct': '72',
#   'jurisdiction_code': '0',
#   'age_group': '18-24',
#   'perp_sex': 'M',
#   'perp_race': 'WHITE HISPANIC',
#   'x_coord_cd': '981988',
#   'y_coord_cd': '177500',
#   'latitude': '40.65388109600008',
#   'longitude': '-74.00815359999996'},
#  {'arrest_key': '206862848',
#   'arrest_date': '2019-12-28T00:00:00.000',
#   'pd_cd': '397',
#   'pd_desc': 'ROBBERY,OPEN AREA UNCLASSIFIED',
#   'ky_cd': '105.0',
#   'ofns_desc': 'ROBBERY',
#   'law_code': 'PL 160102A',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'M',
#   'arrest_precinct': '6',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '984037',
#   'y_coord_cd': '205508',
#   'latitude': '40.730756883000026',
#   'longitude': '-74.00076997599997'},
#  {'arrest_key': '206862657',
#   'arrest_date': '2019-12-28T00:00:00.000',
#   'pd_cd': '922',
#   'pd_desc': 'TRAFFIC,UNCLASSIFIED MISDEMEAN',
#   'ky_cd': '348.0',
#   'ofns_desc': 'VEHICLE AND TRAFFIC LAWS',
#   'law_code': 'VTL1220B01',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'Q',
#   'arrest_precinct': '113',
#   'jurisdiction_code': '97',
#   'age_group': '65+',
#   'perp_sex': 'M',
#   'perp_race': 'ASIAN / PACIFIC ISLANDER',
#   'x_coord_cd': '1046315',
#   'y_coord_cd': '187088',
#   'latitude': '40.67998073800004',
#   'longitude': '-73.77623390699993'},
#  {'arrest_key': '206862460',
#   'arrest_date': '2019-12-28T00:00:00.000',
#   'pd_cd': '781',
#   'pd_desc': 'CRIMINAL DISPOSAL FIREARM 1 &',
#   'ky_cd': '118.0',
#   'ofns_desc': 'DANGEROUS WEAPONS',
#   'law_code': 'PL 2651003',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'K',
#   'arrest_precinct': '63',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1004261',
#   'y_coord_cd': '163171',
#   'latitude': '40.614528721000056',
#   'longitude': '-73.92792511199998'},
#  {'arrest_key': '206861073',
#   'arrest_date': '2019-12-28T00:00:00.000',
#   'pd_cd': '203',
#   'pd_desc': 'TRESPASS 3, CRIMINAL',
#   'ky_cd': '352.0',
#   'ofns_desc': 'CRIMINAL TRESPASS',
#   'law_code': 'PL 140100A',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'K',
#   'arrest_precinct': '67',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '1006465',
#   'y_coord_cd': '178144',
#   'latitude': '40.655621162000045',
#   'longitude': '-73.91993738199994'},
#  {'arrest_key': '206861070',
#   'arrest_date': '2019-12-28T00:00:00.000',
#   'pd_cd': '905',
#   'pd_desc': 'INTOXICATED DRIVING,ALCOHOL',
#   'ky_cd': '347.0',
#   'ofns_desc': 'INTOXICATED & IMPAIRED DRIVING',
#   'law_code': 'VTL11920U2',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'K',
#   'arrest_precinct': '68',
#   'jurisdiction_code': '0',
#   'age_group': '18-24',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '975787',
#   'y_coord_cd': '163892',
#   'latitude': '40.616526269000076',
#   'longitude': '-74.03048468399999'},
#  {'arrest_key': '206860852',
#   'arrest_date': '2019-12-28T00:00:00.000',
#   'pd_cd': '792',
#   'pd_desc': 'WEAPONS POSSESSION 1 & 2',
#   'ky_cd': '118.0',
#   'ofns_desc': 'DANGEROUS WEAPONS',
#   'law_code': 'PL 265031B',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'K',
#   'arrest_precinct': '77',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK',
#   'x_coord_cd': '994879',
#   'y_coord_cd': '186913',
#   'latitude': '40.67971160100007',
#   'longitude': '-73.96168011899994'},
#  {'arrest_key': '206860848',
#   'arrest_date': '2019-12-28T00:00:00.000',
#   'pd_cd': '397',
#   'pd_desc': 'ROBBERY,OPEN AREA UNCLASSIFIED',
#   'ky_cd': '105.0',
#   'ofns_desc': 'ROBBERY',
#   'law_code': 'PL 1601001',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'B',
#   'arrest_precinct': '48',
#   'jurisdiction_code': '0',
#   'age_group': '<18',
#   'perp_sex': 'M',
#   'perp_race': 'BLACK HISPANIC',
#   'x_coord_cd': '1012711',
#   'y_coord_cd': '247067',
#   'latitude': '40.84477935100006',
#   'longitude': '-73.89713478599998'},
#  {'arrest_key': '206860206',
#   'arrest_date': '2019-12-28T00:00:00.000',
#   'pd_cd': '779',
#   'pd_desc': 'PUBLIC ADMINISTRATION,UNCLASSI',
#   'ky_cd': '126.0',
#   'ofns_desc': 'MISCELLANEOUS PENAL LAW',
#   'law_code': 'PL 215510B',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'Q',
#   'arrest_precinct': '106',
#   'jurisdiction_code': '0',
#   'age_group': '18-24',
#   'perp_sex': 'M',
#   'perp_race': 'ASIAN / PACIFIC ISLANDER',
#   'x_coord_cd': '1028605',
#   'y_coord_cd': '187930',
#   'latitude': '40.68239828900005',
#   'longitude': '-73.84007936899997'},
#  {'arrest_key': '206864436',
#   'arrest_date': '2019-12-28T00:00:00.000',
#   'pd_cd': '114',
#   'pd_desc': 'OBSTR BREATH/CIRCUL',
#   'ky_cd': '344.0',
#   'ofns_desc': 'ASSAULT 3 & RELATED OFFENSES',
#   'law_code': 'PL 1211100',
#   'law_cat_cd': 'M',
#   'arrest_boro': 'K',
#   'arrest_precinct': '62',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'WHITE',
#   'x_coord_cd': '983404',
#   'y_coord_cd': '159963',
#   'latitude': '40.60574597200008',
#   'longitude': '-74.00304819199994'},
#  {'arrest_key': '206860593',
#   'arrest_date': '2019-12-28T00:00:00.000',
#   'pd_cd': '439',
#   'pd_desc': 'LARCENY,GRAND FROM OPEN AREAS, UNATTENDED',
#   'ky_cd': '109.0',
#   'ofns_desc': 'GRAND LARCENY',
#   'law_code': 'PL 1553001',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'M',
#   'arrest_precinct': '9',
#   'jurisdiction_code': '0',
#   'age_group': '25-44',
#   'perp_sex': 'M',
#   'perp_race': 'WHITE HISPANIC',
#   'x_coord_cd': '987633',
#   'y_coord_cd': '203880',
#   'latitude': '40.72628777500006',
#   'longitude': '-73.98779600499995'},
#  {'arrest_key': '206865562',
#   'arrest_date': '2019-12-28T00:00:00.000',
#   'pd_cd': '792',
#   'pd_desc': 'WEAPONS POSSESSION 1 & 2',
#   'ky_cd': '118.0',
#   'ofns_desc': 'DANGEROUS WEAPONS',
#   'law_code': 'PL 265031B',
#   'law_cat_cd': 'F',
#   'arrest_boro': 'B',
#   'arrest_precinct': '41',
#   'jurisdiction_code': '0',
#   'age_group': '18-24',
#   'perp_sex': 'M',
#   'perp_race': 'WHITE HISPANIC',
#   'x_coord_cd': '1014604',
#   'y_coord_cd': '238800',
#   'latitude': '40.82208252700008',
#   'longitude': '-73.89033032599998'}]
